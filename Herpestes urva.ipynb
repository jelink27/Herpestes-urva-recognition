# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
 
import torch

print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14302, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 14302 (delta 26), reused 31 (delta 10), pack-reused 14242
# Receiving objects: 100% (14302/14302), 13.59 MiB | 20.44 MiB/s, done.
# Resolving deltas: 100% (9833/9833), done.
# /content/yolov5
#      |████████████████████████████████| 182 kB 9.5 MB/s
#      |████████████████████████████████| 62 kB 721 kB/s
#      |████████████████████████████████| 1.6 MB 29.4 MB/s
# Setup complete. Using torch 1.12.1+cu113 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/木曜大閘蟹/urva_data
# Out:
# urva_image.zip

# %%
# !cp /content/drive/MyDrive/木曜大閘蟹/urva_data/urva_image.zip /content

# %%
# !unzip /content/urva_image.zip -d /content/ #copy過來後unzip
# Out:
# Archive:  /content/urva_image.zip
#    creating: /content/urva_image/
#    creating: /content/urva_image/images/
#    creating: /content/urva_image/images/train/
#   inflating: /content/urva_image/images/train/1.jpg
#   inflating: /content/urva_image/images/train/10.jpg
#   inflating: /content/urva_image/images/train/11.jpg
#   inflating: /content/urva_image/images/train/12.jpg
#   inflating: /content/urva_image/images/train/13.jpg
#   inflating: /content/urva_image/images/train/14.jpg
#   inflating: /content/urva_image/images/train/15.jpg
#   inflating: /content/urva_image/images/train/16.jpg
#   inflating: /content/urva_image/images/train/17.jpg
#   inflating: /content/urva_image/images/train/18.jpg
#   inflating: /content/urva_image/images/train/19.jpg
#   inflating: /content/urva_image/images/train/2.jpg
#   inflating: /content/urva_image/images/train/20.jpg
#   inflating: /content/urva_image/images/train/21.jpg
#   inflating: /content/urva_image/images/train/22.jpg
# ...

# %%
# !python train.py --img 256 --batch 10 --epochs 100 --hyp /content/drive/MyDrive/木曜大閘蟹/urva_yolov5/hyp.custom.yaml  --data /content/drive/MyDrive/木曜大閘蟹/urva_yolov5/Herpestes_urva.yaml  --weights yolov5x.pt --name ''

#權重用yolov5x x是最大型 小一點可以用n or s or l
# Out:
# train: weights=yolov5x.pt, cfg=, data=/content/drive/MyDrive/木曜大閘蟹/urva_yolov5/Herpestes_urva.yaml, hyp=/content/drive/MyDrive/木曜大閘蟹/urva_yolov5/hyp.custom.yaml, epochs=100, batch_size=10, imgsz=256, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
## To save model weights to your google drive!

# !cp 'runs/train/weights/best.pt' /content/drive/MyDrive/木曜大閘蟹/urva_yolov5/

# %%
## check training metrics: /content/yolov5/runs/train/results.png

# %%
# YOLOv5 PyTorch Hub inference: https://github.com/ultralytics/yolov5/issues/36
# Inference with detect.py
# condf 0.25 sigmoid輸出定義0.25以上就是true

# !python detect.py --weights runs/train/weights/best.pt --img 256 --conf 0.1 --source '/content/drive/MyDrive/yolo/yolov5/mask.jpg'
#也可以新增IoU --IoU 預設0.45 預設跟真實交集的框框
# Out:
# detect: weights=['runs/train/weights/best.pt'], source=/content/drive/MyDrive/yolo/yolov5/mask.jpg, data=data/coco128.yaml, imgsz=[256, 256], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86173414 parameters, 0 gradients, 203.8 GFLOPs
# image 1/1 /content/drive/MyDrive/yolo/yolov5/mask.jpg: 160x256 8 urvas, 29.0ms
# Speed: 0.4ms pre-process, 29.0ms inference, 1.4ms NMS per image at shape (1, 3, 256, 256)
# Results saved to runs/detect/exp3

# %%
# local video path or youtube video link

# !python detect.py --weights runs/train/weights/best.pt --source '/content/drive/MyDrive/木曜大閘蟹/2.jpg'
# Out:
# detect: weights=['runs/train/weights/best.pt'], source=/content/drive/MyDrive/木曜大閘蟹/2.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86173414 parameters, 0 gradients, 203.8 GFLOPs
# image 1/1 /content/drive/MyDrive/木曜大閘蟹/2.jpg: 448x640 (no detections), 62.2ms
# Speed: 0.7ms pre-process, 62.2ms inference, 0.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
# local video path or youtube video link

# !python detect.py --weights runs/train/weights/best.pt --source 'https://www.youtube.com/watch?v=qLKBstiddPc'
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 (no detections), 38.9ms
# 0: 384x640 2 urvas, 37.9ms
# 0: 384x640 2 urvas, 35.9ms
# 0: 384x640 2 urvas, 37.8ms
# 0: 384x640 2 urvas, 37.4ms
# 0: 384x640 2 urvas, 38.7ms
# 0: 384x640 1 urva, 35.9ms
# 0: 384x640 1 urva, 36.8ms
# 0: 384x640 1 urva, 36.8ms
# 0: 384x640 1 urva, 37.1ms
# 0: 384x640 1 urva, 38.5ms
# 0: 384x640 1 urva, 35.8ms
# 0: 384x640 1 urva, 37.0ms
# 0: 384x640 1 urva, 38.0ms
# 0: 384x640 1 urva, 36.0ms
# 0: 384x640 (no detections), 36.6ms
# 0: 384x640 (no detections), 36.6ms
# 0: 384x640 (no detections), 37.8ms
# 0: 384x640 (no detections), 38.4ms
# 0: 384x640 (no detections), 36.8ms
# 0: 384x640 (no detections), 36.4ms
# 0: 384x640 (no detections), 36.0ms
# 0: 384x640 (no detections), 36.4ms
# 0: 384x640 (no detections), 36.6ms
# 0: 384x640 (no detections), 37.6ms
# 0: 384x640 (no detections), 39.3ms
# 0: 384x640 (no detections), 37.4ms
# 0: 384x640 (no detections), 36.9ms
# ...

# %%
# !cp /content/yolov5/runs/detect/exp6/watch_v_qLKBstiddPc.mp4 /content/drive/MyDrive/

# %%
# How to get the coordinates of the bounding box in YOLO object detection
# https://github.com/ultralytics/yolov5/issues/388
